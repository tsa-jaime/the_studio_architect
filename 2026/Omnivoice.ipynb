# %% [markdown]
# # 🗣️ OmniVoice
#
# <a href="https://github.com/k2-fsa/OmniVoice">
#   <img src="https://img.shields.io/badge/github-OmniVoice-blue?logo=github" /></a> &nbsp;
# <a href="https://www.youtube.com/@The_Studio_Architect?sub_confirmation=1">
#   <img src="https://img.shields.io/badge/SUBSCRIBE-The_Studio_Architect-red?logo=youtube" />
# </a>

# %% [markdown]
# ### 🛠️ Hardware requirements
#
# We need a GPU.
# Run the following command and check the result.

# %%
# !if nvidia-smi -L |grep "Tesla T4" > /dev/null; then echo -e "\033[0;32m\nThe GPU is OK, you can continue!\n"; else echo -e "\033[0;31m\n╔════════════╗\n║ ⚠️ WARNING ║\n╚════════════╝\nThe GPU is wrong, you should change it!\n"; fi

# %% [markdown]
# #### *If* it says that you should change GPU, go to **Runtime → Change runtime type**, then select the **"T4 GPU"**.

# %% [markdown]
# ![Screenshot_20260221_143604.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot_20260221_143919.png](data:image/png;base64,...)

# %% [markdown]
# ## 👨‍💻 Software requirements
#
# Let's download the code and install the dependencies.

# %%
# !apt-get update && apt-get install -y ffmpeg
# !pip install torch==2.8.0+cu128 torchvision==0.23.0+cu128 torchaudio==2.8.0+cu128 --extra-index-url https://download.pytorch.org/whl/cu128 omnivoice
# !pip uninstall -y torchcodec
# !wget https://raw.githubusercontent.com/tsa-jaime/the_studio_architect/refs/heads/main/2026/omnivoice.py -O run.py
# !export HF_ENDPOINT="https://hf-mirror.com"

# %% [markdown]
# ## ⚡ Run the interface
#
# **Note:** The 1st run is going to download the model, this might take some time.

# %%
# !python run.py --share

# %% [markdown]
# <br>
# <a href="https://www.youtube.com/@The_Studio_Architect?sub_confirmation=1">
#   <img src="https://img.shields.io/badge/SUBSCRIBE-The_Studio_Architect-red?logo=youtube" />
# </a>
